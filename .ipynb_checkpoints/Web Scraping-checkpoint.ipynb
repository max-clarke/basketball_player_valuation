# %%
import re
import requests
import pandas as pd

from bs4 import BeautifulSoup

# %%
# let's take a look Kareem Abdul-Jabbar

url = 'https://www.basketball-reference.com/players/a/abdulka01.html'

df = pd.read_html(url)

# %%
df_kaj = df[0].loc[:, :'PTS']
df_kaj.tail()
# Out:
#      Season   Age   Tm   Lg  Pos     G     GS    MP    FG   FGA  ...     FT%  \
# 16  1985-86  38.0  LAL  NBA    C    79   79.0  33.3   9.6  16.9  ...   0.765
# 17  1986-87  39.0  LAL  NBA    C    78   78.0  31.3   7.2  12.7  ...   0.714
# 18  1987-88  40.0  LAL  NBA    C    80   80.0  28.9   6.0  11.3  ...   0.762
# 19  1988-89  41.0  LAL  NBA    C    74   74.0  22.9   4.2   8.9  ...   0.739
# 20   Career   NaN  NaN  NBA  NaN  1560  625.0  36.8  10.2  18.1  ...   0.721
#
#     ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 16  1.7  4.4   6.1  3.5  0.8  1.6  2.6  3.1  23.4
# 17  1.9  4.8   6.7  2.6  0.6  1.2  2.4  3.1  17.5
# 18  1.5  4.5   6.0  1.7  0.6  1.2  2.0  2.7  14.6
# 19  1.4  3.1   4.5  1.0  0.5  1.1  1.3  2.6  10.1
# 20  2.4  7.6  11.2  3.6  0.9  2.6  2.7  3.0  24.6
#
# [5 rows x 30 columns]

# %% [markdown]
# What question to answer?
#
# - Stats for teams starting lineup in previous year --> number of wins in regular season?
#
# Let's start with the spurs in 2006:

# %%
# looks like top 5 rank can be a decent standin for starting lineup.

url = 'https://www.basketball-reference.com/teams/SAS/2006.html'

response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, 'lxml')

# <!-- is open comment

# --> is close comment

# %% [markdown]
# We have discovered that the tables are commented out. The theory is that this is done in order to make the tables sortable. There's perhaps a javascript applet that applies here.

# %%
# uncomment the html
macaroni = soup.prettify().split('<!--')
macaroni = [mac.strip('-->') for mac in macaroni]

macaroni[20] # example table
# Out:
# '\n   <div class="table_outer_container">\n      <div class="overthrow table_container" id="div_team_and_opponent">\n  <table class="suppress_all stats_table" id="team_and_opponent" data-cols-to-freeze=1><caption>Team and Opponent Stats Table</caption>\n   <colgroup><col><col><col><col><col><col><col><col><col><col><col><col><col><col><col><col><col><col><col><col><col><col><col><col></colgroup>\n   <thead>      \n      <tr>\n         <th aria-label="&nbsp;" data-stat="player" scope="col" class=" poptip sort_default_asc center" >&nbsp;</th>\n         <th aria-label="Games" data-stat="g" scope="col" class=" poptip sort_default_asc center" data-tip="Games" >G</th>\n         <th aria-label="Minutes Played" data-stat="mp" scope="col" class=" poptip center" data-tip="Minutes Played" >MP</th>\n         <th aria-label="Field Goals" data-stat="fg" scope="col" class=" poptip center" data-tip="Field Goals" >FG</th>\n         <th aria-label="Field Goal Attempts" data-stat="fga" scope="col" class=" poptip center" data-tip="Field Goal Attempts" >FGA</th>\n         <th aria-label="Field Goal Percentage" data-stat="fg_pct" scope="col" class=" poptip center" data-tip="Field Goal Percentage" >FG%</th>\n         <th aria-label="3-Point Field Goals" data-stat="fg3" scope="col" class=" poptip center" data-tip="3-Point Field Goals" >3P</th>\n         <th aria-label="3-Point Field Goal Attempts" data-stat="fg3a" scope="col" class=" poptip center" data-tip="3-Point Field Goal Attempts" >3PA</th>\n         <th aria-label="3-Point Field Goal Percentage" data-stat="fg3_pct" scope="col" class=" poptip center" data-tip="3-Point Field Goal Percentage" >3P%</th>\n         <th aria-label="2-Point Field Goals" data-stat="fg2" scope="col" class=" poptip center" data-tip="2-Point Field Goals" >2P</th>\n         <th aria-label="2-point Field Goal Attempts" data-stat="fg2a" scope="col" class=" poptip center" data-tip="2-point Field Goal Attempts" >2PA</th>\n         <th aria-label="2-Point Field Goal Percentage" data-stat="fg2_pct" scope="col" class=" poptip center" data-tip="2-Point Field Goal Percentage" >2P%</th>\n         <th aria-label="Free Throws" data-stat="ft" scope="col" class=" poptip center" data-tip="Free Throws" >FT</th>\n         <th aria-label="Free Throw Attempts" data-stat="fta" scope="col" class=" poptip center" data-tip="Free Throw Attempts" >FTA</th>\n         <th aria-label="Free Throw Percentage" data-stat="ft_pct" scope="col" class=" poptip center" data-tip="Free Throw Percentage" >FT%</th>\n         <th aria-label="Offensive Rebounds" data-stat="orb" scope="col" class=" poptip center" data-tip="Offensive Rebounds" >ORB</th>\n         <th aria-label="Defensive Rebounds" data-stat="drb" scope="col" class=" poptip center" data-tip="Defensive Rebounds" >DRB</th>\n         <th aria-label="Total Rebounds" data-stat="trb" scope="col" class=" poptip center" data-tip="Total Rebounds" >TRB</th>\n         <th aria-label="Assists" data-stat="ast" scope="col" class=" poptip center" data-tip="Assists" >AST</th>\n         <th aria-label="Steals" data-stat="stl" scope="col" class=" poptip center" data-tip="Steals" >STL</th>\n         <th aria-label="Blocks" data-stat="blk" scope="col" class=" poptip center" data-tip="Blocks" >BLK</th>\n         <th aria-label="Turnovers" data-stat="tov" scope="col" class=" poptip center" data-tip="Turnovers" >TOV</th>\n         <th aria-label="Personal Fouls" data-stat="pf" scope="col" class=" poptip center" data-tip="Personal Fouls" >PF</th>\n         <th aria-label="Points" data-stat="pts" scope="col" class=" poptip center" data-tip="Points" >PTS</th>\n      </tr>\n      \n   </thead>\n   <tbody>\n<tr ><th scope="row" class="left " data-stat="player" >Team</th><td class="center " data-stat="g" >82</td><td class="center " data-stat="mp" >19805</td><td class="center " data-stat="fg" >2993</td><td class="center " data-stat="fga" >6342</td><td class="center " data-stat="fg_pct" >.472</td><td class="center " data-stat="fg3 ...

# %%
sample_table = macaroni[20] # this appears to be the first table commented out

# note: there is a table that isn't commented out

soop = BeautifulSoup(sample_table, 'lxml') # parse commented out html

print(soop.prettify()) # looks pretty good
# Out:
# <html>
#  <body>
#   <div class="table_outer_container">
#    <div class="overthrow table_container" id="div_team_and_opponent">
#     <table class="suppress_all stats_table" data-cols-to-freeze="1" id="team_and_opponent">
#      <caption>
#       Team and Opponent Stats Table
#      </caption>
#      <colgroup>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#       <col/>
#      </colgroup>
#      <thead>
#       <tr>
#        <th aria-label=" " class=" poptip sort_default_asc center" data-stat="player" scope="col">
#        </th>
#        <th aria-label="Games" class=" poptip sort_default_asc center" data-stat="g" data-tip="Games" scope="col">
#         G
#        </th>
#        <th aria-label="Minutes Played" class=" poptip center" data-stat="mp" data-tip="Minutes Played" scope="col">
#         MP
#        </th>
#        <th aria-label="Field Goals" class=" poptip center" data-stat="fg" data-tip="Field Goals" scope="col">
#         FG
#        </th>
#        <th aria-label="Field Goal Attempts" class=" poptip center" data-stat="fga" data-tip="Field Goal Attempts" scope="col">
#         FGA
#        </th>
#        <th aria-label="Field Goal Percentage" class=" poptip center" data-stat="fg_pct" data-tip="Field Goal Percentage" scope="col">
#         FG%
#        </th>
#        <th aria-label="3-Point Field Goals" class=" poptip center" data-stat="fg3" data-tip="3-Point Field Goals" scope="col">
#         3P
#        </th>
#        <th aria-label="3-Point Field Goal Attempts" class=" poptip center" data-stat="fg3a" data-tip="3-Point Field Goal Attempts" scope="col">
#         3PA
#        </th>
#        <th aria-label="3-Point Field Goal Percentage" class=" poptip center" data-stat="fg3_pct" data-tip="3-Point Field Goal Percentage" scope="col">
#         3P%
#        </th>
#        <th aria-label="2-Point Field Goals" class=" poptip center" data-stat="fg2" data-tip="2-Point Field Goals" scope="col">
#         2P
#        </th>
#        <th aria-label="2-point Field Goal Attempts" class=" poptip center" data-stat="fg2a" data-tip="2-point Field Goal Attempts" scope="col">
#         2PA
#        </th>
#        <th aria-label="2-Point Field Goal Percentage" class=" poptip center" data-stat="fg2_pct" data-tip="2-Point Field Goal Percentage" scope="col">
#         2P%
#        </th>
#        <th aria-label="Free Throws" class=" poptip center" data-stat="ft" data-tip="Free Throws" scope="col">
#         FT
#        </th>
#        <th aria-label="Free Throw Attempts" class=" poptip center" data-stat="fta" data-tip="Free Throw Attempts" scope="col">
#         FTA
#        </th>
#        <th aria-label="Free Throw Percentage" class=" poptip center" data-stat="ft_pct" data-tip="Free Throw Percentage" scope="col">
#         FT%
#        </th>
#        <th aria-label="Offensive Rebounds" class=" poptip center" data-stat="orb" data-tip="Offensive Rebounds" scope="col">
#         ORB
#        </th>
#        <th aria-label="Defensive Rebounds" class=" poptip center" data-stat="drb" data-tip="Defensive Rebounds" scope="col">
#         DRB
#        </th>
#        <th aria-label="Total Rebounds" class=" poptip center" data-stat="trb" data-tip="Total Rebounds" scope="col">
#         TRB
#        </th>
#        <th aria-label="Assists" class=" poptip center" data-stat="ast" data-tip="Assists" scope="col">
#         AST
#        </th>
#        <th aria-label="Steals" class=" poptip center" data-stat="stl" data-tip="Steals" scope="col">
#         STL
#        </th>
#        <th aria-label="Blocks" class=" poptip center" data-stat="blk" data-tip="Blocks" scope="col">
#         BLK
#        </th>
#        <th aria-label="Turnovers" class=" poptip center" data-stat="tov" data-tip="Turnovers" scope="col">
#         TOV
#        </th>
#        <th aria-label="Personal Fouls" class=" poptip center" data-stat="pf" data-tip="Personal Fouls" scope="col">
#         PF
#        </th>
#        <th aria-label="Points" class=" poptip center" data-stat="pts" data-tip="Points" scope="col">
#         PTS
#        </th>
#       </tr>
#      </thead>
#      <tbody>
#       <tr>
#        <th class="left " data-stat="player" scope="row">
#         Team
#        </th>
#        <td class="center " data-stat="g">
#         82
#        </td>
#        <td class="center " data-stat="mp">
#         19805
#        </td>
#        <td class="center " data-stat="fg">
#         2993
#        </td>
#        <td class="center " data-stat="fga">
#         6342
#        </td>
#        <td class="center " data-stat="fg_pct">
#         .472
#        </td>
#        <td class="center " data-stat="fg3">
#         524
#        </td>
#        <td class="center " data-stat="fg3a">
#         1362
#        </td>
#        <td class="center " data-stat="fg3_pct">
#         .385
#        </td>
#        <td class="center " data-stat="fg2">
#         2469
#        </td>
#        <td class="center " data-stat="fg2a">
#         4980
#        </td>
#        <td class="center " data-stat="fg2_pct">
#         .496
#        </td>
#        <td class="center " data-stat="ft">
#         1327
#        </td>
#        <td class="center " data-stat="fta">
#         1891
#        </td>
#        <td class="center " data-stat="ft_pct">
#         .702
#        </td>
#        <td class="center " data-stat="orb">
#         851
#        </td>
#        <td class="center " data-stat="drb">
#         2548
#        </td>
#        <td class="center " data-stat="trb">
#         3399
#        </td>
#        <td class="center " data-stat="ast">
#         1717
#        </td>
#        <td class="center " data-stat="stl">
#         543
#        </td>
#        <td class="center " data-stat="blk">
#         467
#        </td>
#        <td class="center " data-stat="tov">
#         1126
#        </td>
#        <td class="center " data-stat="pf">
#         1714
#        </td>
#        <td class="center " data-stat="pts">
#         7837
#        </td>
#       </tr>
#       <tr>
#        <th class="left " data-stat="player" scope="row">
#         Team/G
#        </th>
#        <td class="center iz" data-stat="g">
#        </td>
#        <td class="center " data-stat="mp_per_g">
#         241.5
#        </td>
#        <td class="center " data-stat="fg_per_g">
#         36.5
#        </td>
#        <td class="center " data-stat="fga_per_g">
#         77.3
#        </td>
#        <td class="center " data-stat="fg_pct">
#         .472
#        </td>
#        <td class="center " data-stat="fg3_per_g">
#         6.4
#        </td>
#        <td class="center " data-stat="fg3a_per_g">
#         16.6
#        </td>
#        <td class="center " data-stat="fg3_pct">
#         .385
#        </td>
#        <td class="center " data-stat="fg2_per_g">
#         30.1
#        </td>
#        <td class="center " data-stat="fg2a_per_g">
#         60.7
#        </td>
#        <td class="center " data-stat="fg2_pct">
#         .496
#        </td>
#        <td class="center " data-stat="ft_per_g">
#         16.2
#        </td>
#        <td class="center " data-stat="fta_per_g">
#         23.1
#        </td>
#        <td class="center " data-stat="ft_pct">
#         .702
#        </td>
#        <td class="center " data-stat="orb_per_g">
#         10.4
#        </td>
#        <td class="center " data-stat="drb_per_g">
#         31.1
#        </td>
#        <td class="center " data-stat="trb_per_g">
#         41.5
#        </td>
#        <td class="center " data-stat="ast_per_g">
#         20.9
#        </td>
#        <td class="center " data-stat="stl_per_g">
#         6.6
#        </td>
#        <td class="center " data-stat="blk_per_g">
#         5.7
#        </td>
#        <td class="center " data-stat="tov_per_g">
#         13.7
#        </td>
#        <td class="center " data-stat="pf_per_g">
#         20.9
#        </td>
#        <td class="center " data-stat="pts_per_g">
#         95.6
#        </td>
#       </tr>
#       <tr>
#        <th class="left " data-stat="player" scope="row">
#         Lg Rank
#        </th>
#        <td class="center iz" data-stat="g">
#        </td>
#        <td class="center " data-stat="mp">
#         24
#        </td>
#        <td class="center " data-stat="fg">
#         8
#        </td>
#        <td class="center " data-stat="fga">
#         20
#        </td>
#        <td class="center " data-stat="fg_pct">
#         4
#        </td>
#        <td class="center " data-stat="fg3">
#         10
#        </td>
#        <td class="center " data-stat="fg3a">
#         16
#        </td>
#        <td class="center " data-stat="fg3_pct">
#         2
#        </td>
#        <td class="center " data-stat="fg2">
#         16
#        </td>
#        <td class="center " data-stat="fg2a">
#         23
#        </td>
#        <td class="center " data-stat="fg2_pct">
#         3
#        </td>
#        <td class="center " data-stat="ft">
#         29
#        </td>
#        <td class="center " data-stat="fta">
#         29
#        </td>
#        <td class="center " data-stat="ft_pct">
#         28
#        </td>
#        <td class="center " data-stat="orb">
#         23
#        </td>
#        <td class="center " data-stat="drb">
#         7
#        </td>
#        <td class="center " data-stat="trb">
#         12
#        </td>
#        <td class="center " data-stat="ast">
#         10
#        </td>
#        <td class="center " data-stat="stl">
#         23
#        </td>
#        <td class="center " data-stat="blk">
#         6
#        </td>
#        <td class="center " data-stat="tov">
#         7
#        </td>
#        <td class="center " data-stat="pf">
#         5
#        </td>
#        <td class="center " data-stat="pts">
#         21
#        </td>
#       </tr>
#       <tr>
#        <th class="left " data-stat="player" scope="row">
#         Year/Year
#        </th>
#        <td class="center iz" data-stat="g">
#        </td>
#        <td class="center " data-stat="mp_per_g">
#         <span>
#          0.0%
#         </span>
#        </td>
#        <td class="center " data-stat="fg_per_g">
#         <span>
#          2.4%
#         </span>
#        </td>
#        <td class="center " data-stat="fga_per_g">
#         <span>
#          -1.7%
#         </span>
#        </td>
#        <td class="center " data-stat="fg_pct">
#         <span>
#          +.019
#         </span>
#        </td>
#        <td class="center " data-stat="fg3_per_g">
#         <span>
#          3.4%
#         </span>
#        </td>
#        <td class="center " data-stat="fg3a_per_g">
#         <span>
#          -2.4%
#         </span>
#        </td>
#        <td class="center " data-stat="fg3_pct">
#         <span>
#          +.021
#         </span>
#        </td>
#        <td class="center " data-stat="fg2_per_g">
#         <span>
#          2.2%
#         </span>
#        </td>
#        <td class="center " data-stat="fg2a_per_g">
#         <span>
#          -1.5%
#         </span>
#        </td>
#        <td class="center " data-stat="fg2_pct">
#         <span>
#          +.018
#         </span>
#        </td>
#        <td class="center " data-stat="ft_per_g">
#         <span>
#          -13.6%
#         </span>
#        </td>
#        <td class="center " data-stat="fta_per_g">
#         <span>
#          -10.8%
#         </span>
#        </td>
#        <td class="center " data-stat="ft_pct">
#         <span>
#          -.022
#         </span>
#        </td>
#        <td class="center " data-stat="orb_per_g">
#         <span>
#          -13.8%
#         </span>
#        </td>
#        <td class="center " data-stat="drb_per_g">
#         <span>
#          2.4%
#         </span>
#        </td>
#        <td class="center " data-stat="trb_per_g">
#         <span>
#          -2.2%
#         </span>
#        </td>
#        <td class="center " data-stat="ast_per_g">
#         <span>
#          -3.0%
#         </span>
#        </td>
#        <td class="center " data-stat="stl_per_g">
#         <span>
#          -11.4%
#         </span>
#        </td>
#        <td class="center " data-stat="blk_per_g">
#         <span>
#          -14.0%
#         </span>
#        </td>
#        <td class="center " data-stat="tov_per_g">
#         <span>
#          0.0%
#         </span>
#        </td>
#        <td class="center " data-stat="pf_per_g">
#         <span>
#          -0.2%
#         </span>
#        </td>
#        <td class="center " data-stat="pts_per_g">
#         <span>
#          -0.6%
#         </span>
#        </td>
#       </tr>
#       <colgroup>
#       </colgroup>
#       <thead>
#       </thead>
#       <tr>
#        <th class="left " data-stat="player" scope="row">
#         Opponent
#        </th>
#        <td class="center " data-stat="g">
#         82
#        </td>
#        <td class="center " data-stat="mp">
#         19805
#        </td>
#        <td class="center " data-stat="opp_fg">
#         2782
#        </td>
#        <td class="center " data-stat="opp_fga">
#         6420
#        </td>
#        <td class="center " data-stat="opp_fg_pct">
#         .433
#        </td>
#        <td class="center " data-stat="opp_fg3">
#         300
#        </td>
#        <td class="center " data-stat="opp_fg3a">
#         886
#        </td>
#        <td class="center " data-stat="opp_fg3_pct">
#         .339
#        </td>
#        <td class="center " data-stat="opp_fg2">
#         2482
#        </td>
#        <td class="center " data-stat="opp_fg2a">
#         5534
#        </td>
#        <td class="center " data-stat="opp_fg2_pct">
#         .449
#        </td>
#        <td class="center " data-stat="opp_ft">
#         1414
#        </td>
#        <td class="center " data-stat="opp_fta">
#         1912
#        </td>
#        <td class="center " data-stat="opp_ft_pct">
#         .740
#        </td>
#        <td class="center " data-stat="opp_orb">
#         886
#        </td>
#        <td class="center " data-stat="opp_drb">
#         2417
#        </td>
#        <td class="center " data-stat="opp_trb">
#         3303
#        </td>
#        <td class="center " data-stat="opp_ast">
#         1336
#        </td>
#        <td class="center " data-stat="opp_stl">
#         599
#        </td>
#        <td class="center " data-stat="opp_blk">
#         343
#        </td>
#        <td class="center " data-stat="opp_tov">
#         1136
#        </td>
#        <td class="center " data-stat="opp_pf">
#         1709
#        </td>
#        <td class="center " data-stat="opp_pts">
#         7278
#        </td>
#       </tr>
#       <tr>
#        <th class="left " data-stat="player" scope="row">
#         Opponent/G
#        </th>
#        <td class="center iz" data-stat="g">
#        </td>
#        <td class="center " data-stat="mp_per_g">
#         241.5
#        </td>
#        <td class="center " data-stat="opp_fg_per_g">
#         33.9
#        </td>
#        <td class="center " data-stat="opp_fga_per_g">
#         78.3
#        </td>
#        <td class="center " data-stat="opp_fg_pct">
#         .433
#        </td>
#        <td class="center " data-stat="opp_fg3_per_g">
#         3.7
#        </td>
#        <td class="center " data-stat="opp_fg3a_per_g">
#         10.8
#        </td>
#        <td class="center " data-stat="opp_fg3_pct">
#         .339
#        </td>
#        <td class="center " data-stat="opp_fg2_per_g">
#         30.3
#        </td>
#        <td class="center " data-stat="opp_fg2a_per_g">
#         67.5
#        </td>
#        <td class="center " data-stat="opp_fg2_pct">
#         .449
#        </td>
#        <td class="center " data-stat="opp_ft_per_g">
#         17.2
#        </td>
#        <td class="center " data-stat="opp_fta_per_g">
#         23.3
#        </td>
#        <td class="center " data-stat="opp_ft_pct">
#         .740
#        </td>
#        <td class="center " data-stat="opp_orb_per_g">
#         10.8
#        </td>
#        <td class="center " data-stat="opp_drb_per_g">
#         29.5
#        </td>
#        <td class="center " data-stat="opp_trb_per_g">
#         40.3
#        </td>
#        <td class="center " data-stat="opp_ast_per_g">
#         16.3
#        </td>
#        <td class="center " data-stat="opp_stl_per_g">
#         7.3
#        </td>
#        <td class="center " data-stat="opp_blk_per_g">
#         4.2
#        </td>
#        <td class="center " data-stat="opp_tov_per_g">
#         13.9
#        </td>
#        <td class="center " data-stat="opp_pf_per_g">
#         20.8
#        </td>
#        <td class="center " data-stat="opp_pts_per_g">
#         88.8
#        </td>
#       </tr>
#       <tr>
#        <th class="left " data-stat="player" scope="row">
#         Lg Rank
#        </th>
#        <td class="center iz" data-stat="g">
#        </td>
#        <td class="center " data-stat="mp">
#         24
#        </td>
#        <td class="center " data-stat="opp_fg">
#         6
#        </td>
#        <td class="center " data-stat="opp_fga">
#         11
#        </td>
#        <td class="center " data-stat="opp_fg_pct">
#         3
#        </td>
#        <td class="center " data-stat="opp_fg3">
#         1
#        </td>
#        <td class="center " data-stat="opp_fg3a">
#         1
#        </td>
#        <td class="center " data-stat="opp_fg3_pct">
#         3
#        </td>
#        <td class="center " data-stat="opp_fg2">
#         15
#        </td>
#        <td class="center " data-stat="opp_fg2a">
#         29
#        </td>
#        <td class="center " data-stat="opp_fg2_pct">
#         3
#        </td>
#        <td class="center " data-stat="opp_ft">
#         3
#        </td>
#        <td class="center " data-stat="opp_fta">
#         3
#        </td>
#        <td class="center " data-stat="opp_ft_pct">
#         11
#        </td>
#        <td class="center " data-stat="opp_orb">
#         12
#        </td>
#        <td class="center " data-stat="opp_drb">
#         14
#        </td>
#        <td class="center " data-stat="opp_trb">
#         10
#        </td>
#        <td class="center " data-stat="opp_ast">
#         1
#        </td>
#        <td class="center " data-stat="opp_stl">
#         21
#        </td>
#        <td class="center " data-stat="opp_blk">
#         6
#        </td>
#        <td class="center " data-stat="opp_tov">
#         23
#        </td>
#        <td class="center " data-stat="opp_pf">
#         3
#        </td>
#        <td class="center " data-stat="opp_pts">
#         2
#        </td>
#       </tr>
#       <tr>
#        <th class="left " data-stat="player" scope="row">
#         Year/Year
#        </th>
#        <td class="center iz" data-stat="g">
#        </td>
#        <td class="center " data-stat="mp_per_g">
#         <span>
#          0.0%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_fg_per_g">
#         <span>
#          2.6%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_fga_per_g">
#         <span>
#          1.0%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_fg_pct">
#         <span>
#          +.007
#         </span>
#        </td>
#        <td class="center " data-stat="opp_fg3_per_g">
#         <span>
#          -7.1%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_fg3a_per_g">
#         <span>
#          0.6%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_fg3_pct">
#         <span>
#          -.028
#         </span>
#        </td>
#        <td class="center " data-stat="opp_fg2_per_g">
#         <span>
#          3.9%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_fg2a_per_g">
#         <span>
#          1.0%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_fg2_pct">
#         <span>
#          +.012
#         </span>
#        </td>
#        <td class="center " data-stat="opp_ft_per_g">
#         <span>
#          -5.8%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_fta_per_g">
#         <span>
#          -2.2%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_ft_pct">
#         <span>
#          -.028
#         </span>
#        </td>
#        <td class="center " data-stat="opp_orb_per_g">
#         <span>
#          -0.8%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_drb_per_g">
#         <span>
#          0.6%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_trb_per_g">
#         <span>
#          0.2%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_ast_per_g">
#         <span>
#          -3.5%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_stl_per_g">
#         <span>
#          0.8%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_blk_per_g">
#         <span>
#          -18.5%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_tov_per_g">
#         <span>
#          -8.4%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_pf_per_g">
#         <span>
#          -9.6%
#         </span>
#        </td>
#        <td class="center " data-stat="opp_pts_per_g">
#         <span>
#          0.4%
#         </span>
#        </td>
#       </tr>
#      </tbody>
#     </table>
#    </div>
#   </div>
#   --&gt;
#  </body>
# </html>

# %%
# TODO: attempt to get a table-like structure from this data

# put into dataframe
